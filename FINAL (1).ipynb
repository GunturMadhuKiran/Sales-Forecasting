# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/2/Desktop/MAJOR/ECOMMERCE_LOGS.csv")
# Out:
# C:\Users\2\AppData\Local\Temp\ipykernel_7648\806113779.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/2/Desktop/MAJOR/ECOMMERCE_LOGS.csv")

# %%
df
# Out:
#        accessed_date  duration_(secs) network_protocol               ip  \
# 0            43:57.2             2533            TCP       1.10.195.126
# 1            43:57.2             4034            TCP        1.1.217.211
# 2            43:26.1             1525            TCP      1.115.198.107
# 3            43:26.1             4572            TCP      1.121.152.143
# 4            17:09.0             3652            TCP      1.123.135.213
# ...              ...              ...              ...              ...
# 172833       42:01.3             4372            TCP     94.197.121.229
# 172834       10:17.3             2167            TCP     129.110.241.72
# 172835       10:17.3             2725            TCP    185.119.252.121
# 172836       52:58.3             3728            TCP     185.145.107.23
# 172837       52:58.3             3420            TCP      202.69.12.251
#
#          bytes    accessed_Ffom  age  gender country membership language  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172838 entries, 0 to 172837
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   accessed_date     172838 non-null  object
#  1   duration_(secs)   172838 non-null  int64
#  2   network_protocol  172838 non-null  object
#  3   ip                172838 non-null  object
#  4   bytes             172838 non-null  int64
#  5   accessed_Ffom     172838 non-null  object
#  6   age               99457 non-null   object
#  7   gender            172838 non-null  object
#  8   country           172838 non-null  object
#  9   membership        172838 non-null  object
#  10  language          172838 non-null  object
#  11  sales             172838 non-null  float64
#  12  returned          172838 non-null  object
#  13  returned_amount   172838 non-null  float64
#  14  pay_method        172838 non-null  object
# dtypes: float64(2), int64(2), object(11)
# ...

# %%
df.isnull().sum()
# Out:
# accessed_date           0
# duration_(secs)         0
# network_protocol        0
# ip                      0
# bytes                   0
# accessed_Ffom           0
# age                 73381
# gender                  0
# country                 0
# membership              0
# language                0
# sales                   0
# returned                0
# returned_amount         0
# pay_method              0
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#       accessed_date  duration_(secs) network_protocol               ip  \
# 0           43:57.2             2533            TCP       1.10.195.126
# 1           43:57.2             4034            TCP        1.1.217.211
# 2           43:26.1             1525            TCP      1.115.198.107
# 3           43:26.1             4572            TCP      1.121.152.143
# 4           17:09.0             3652            TCP      1.123.135.213
# ...             ...              ...              ...              ...
# 99452       56:59.3             3439            TCP     221.113.41.218
# 99453       57:46.8             2479            TCP    221.124.124.226
# 99454       57:46.8             4231            TCP     221.125.18.121
# 99455       57:59.6             3807            TCP      221.127.8.150
# 99456       57:59.6             4479            TCP     221.138.38.166
#
#         bytes    accessed_Ffom age  gender country membership language  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)
# Out:
# C:\Users\2\AppData\Local\Temp\ipykernel_7648\3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
from scipy import stats

# %%
df.describe()
# Out:
#        duration_(secs)          bytes         sales  returned_amount
# count     99457.000000   99457.000000  99457.000000     99457.000000
# mean       3251.364328    1402.250621    360.273099        72.080813
# std        1011.849589    7484.018496    736.018297       361.073570
# min        1500.000000      28.000000      0.000000         0.000000
# 25%        2373.000000     250.000000      0.000000         0.000000
# 50%        3251.000000     579.000000     40.660000         0.000000
# 75%        4128.000000    2267.000000    244.550000         0.000000
# max        5000.000000  897983.000000  11199.968000      7999.980000

# %%
df.shape
# Out:
# (99457, 15)

# %%
print(df.isnull().sum())
# Out:
# accessed_date       0
# duration_(secs)     0
# network_protocol    0
# ip                  0
# bytes               0
# accessed_Ffom       0
# age                 0
# gender              0
# country             0
# membership          0
# language            0
# sales               0
# returned            0
# returned_amount     0
# pay_method          0
# dtype: int64

# %%
df = df.drop('accessed_date', axis=1)

# %%
df.shape
# Out:
# (99457, 14)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='accessed_Ffom', y='sales', data=df)
plt.title('sales by accessed_From')
plt.xlabel('accessed_Ffom')
plt.ylabel('sales')
plt.show()

# %%
df
# Out:
#        duration_(secs) network_protocol               ip   bytes  \
# 0                 2533            TCP       1.10.195.126   20100
# 1                 4034            TCP        1.1.217.211   20500
# 2                 1525            TCP      1.115.198.107   90100
# 3                 4572            TCP      1.121.152.143  100300
# 4                 3652            TCP      1.123.135.213  270200
# ...                ...              ...              ...     ...
# 99452             3439            TCP     221.113.41.218    4582
# 99453             2479            TCP    221.124.124.226     314
# 99454             4231            TCP     221.125.18.121     281
# 99455             3807            TCP      221.127.8.150      40
# 99456             4479            TCP     221.138.38.166      46
#
#          accessed_Ffom age  gender country membership language      sales  \
# 0               Chrome  28  Female      CA     Normal  English   261.9600
# ...

# %%
df = df.drop('ip', axis=1)

# %%
df.shape
# Out:
# (99457, 13)

# %%
df.head
# Out:
# <bound method NDFrame.head of        duration_(secs) network_protocol   bytes    accessed_Ffom age  gender  \
# 0                 2533            TCP     20100           Chrome  28  Female
# 1                 4034            TCP     20500  Mozilla Firefox  21    Male
# 2                 1525            TCP     90100  Mozilla Firefox  20    Male
# 3                 4572            TCP    100300  Mozilla Firefox  66  Female
# 4                 3652            TCP    270200  Mozilla Firefox  53  Female
# ...                ...              ...     ...              ...  ..     ...
# 99452             3439            TCP      4582   Microsoft Edge  45  Female
# 99453             2479            TCP       314   Microsoft Edge  27    Male
# 99454             4231            TCP       281   Microsoft Edge  63    Male
# 99455             3807            TCP        40           Safari  56    Male
# 99456             4479            TCP        46           Safari  36  Female
#
# ...

# %%
df.shape
# Out:
# (99457, 13)

# %%
df.head()
# Out:
#    duration_(secs) network_protocol   bytes    accessed_Ffom age  gender  \
# 0             2533            TCP     20100           Chrome  28  Female
# 1             4034            TCP     20500  Mozilla Firefox  21    Male
# 2             1525            TCP     90100  Mozilla Firefox  20    Male
# 3             4572            TCP    100300  Mozilla Firefox  66  Female
# 4             3652            TCP    270200  Mozilla Firefox  53  Female
#
#   country membership language     sales returned  returned_amount   pay_method
# 0      CA     Normal  English  261.9600       No              0.0  Credit Card
# 1      AR     Normal  English  731.9400       No              0.0   Debit Card
# 2      PL     Normal  English   14.6200       No              0.0         Cash
# 3      IN     Normal  Spanish  957.5775       No              0.0  Credit Card
# 4      KR     Normal  Spanish   22.3680       No              0.0         Cash

# %%
print(df.columns)
# Out:
# Index(['duration_(secs)', 'network_protocol', 'bytes', 'accessed_Ffom', 'age',
#        'gender', 'country', 'membership', 'language', 'sales', 'returned',
#        'returned_amount', 'pay_method'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99457 entries, 0 to 99456
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   duration_(secs)   99457 non-null  int64
#  1   network_protocol  99457 non-null  object
#  2   bytes             99457 non-null  int64
#  3   accessed_Ffom     99457 non-null  object
#  4   age               99457 non-null  object
#  5   gender            99457 non-null  object
#  6   country           99457 non-null  object
#  7   membership        99457 non-null  object
#  8   language          99457 non-null  object
#  9   sales             99457 non-null  float64
#  10  returned          99457 non-null  object
#  11  returned_amount   99457 non-null  float64
#  12  pay_method        99457 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 10.6+ MB

# %%
# Specify the string you want to find
target_string = '--'

# Check if the string is present in any column
contains_target = df.apply(lambda row: target_string in str(row), axis=1)

# Filter the DataFrame based on the condition
result_df = df[contains_target]

# Display or print the rows where the string is found
print(result_df)
# Out:
#        duration_(secs) network_protocol  bytes accessed_Ffom age   gender  \
# 251               2819             HTTP  21160        Others  --  Unknown
# 1555              1739             HTTP    383   Android App  --  Unknown
# 1782              3682             HTTP     46        Chrome  --  Unknown
# 1783              2891             HTTP    264        Chrome  --  Unknown
# 2648              2222             HTTP    387        Safari  --  Unknown
# ...                ...              ...    ...           ...  ..      ...
# 99310             4237            TCP       44   Android App  --  Unknown
# 99311             2578            TCP      808   Android App  --  Unknown
# 99312             3265            TCP    14967   Android App  --  Unknown
# 99339             1813            TCP      485       IOS App  --  Unknown
# 99340             4079            TCP     1426       IOS App  --  Unknown
#
#       country     membership language  sales returned  returned_amount  \
# ...

# %%
df['age'] = df['age'].replace('--', '0')

# %%
numerical_variables = ['duration_(secs)', 'bytes','age','sales','returned_amount' ]

# Calculate the correlation matrix
correlation_matrix = df[numerical_variables].corr()

print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                  duration_(secs)     bytes       age     sales  \
# duration_(secs)         1.000000  0.005464  0.002797 -0.002576
# bytes                   0.005464  1.000000  0.048210  0.013451
# age                     0.002797  0.048210  1.000000  0.153846
# sales                  -0.002576  0.013451  0.153846  1.000000
# returned_amount         0.003913  0.008230  0.059596 -0.097717
#
#                  returned_amount
# duration_(secs)         0.003913
# bytes                   0.008230
# age                     0.059596
# sales                  -0.097717
# returned_amount         1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'correlation_matrix' is your correlation matrix
# If not, replace it with the actual variable name containing your correlation matrix

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
#Scatter plot to visualize the relationship between 'bytes' and 'sales'.
plt.scatter(df['bytes'], df['sales'])
plt.xlabel('bytes')
plt.ylabel('sales')
plt.title('Scatter Plot: Bytes vs. Sales')
plt.show()

# %%
df = pd.DataFrame(df)

# Find the highest and lowest age values
highest_age = df['age'].max()
lowest_age = df['age'].min()

print(f'Highest age: {highest_age}')
print(f'Lowest age: {lowest_age}')
# Out:
# Highest age: 69
# Lowest age: 0

# %%
bytes_df = pd.DataFrame(df)

# Find the highest and lowest values in the 'bytes' column
highest_value = bytes_df['bytes'].max()
lowest_value = bytes_df['bytes'].min()

# Print the results
print("Highest Value:", highest_value)
print("Lowest Value:", lowest_value)
# Out:
# Highest Value: 897983
# Lowest Value: 28

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


data = {
    'Age': np.random.randint(0, 70, size=50),
    'Bytes': np.random.randint(28, 897984, size=50)
}

df = pd.DataFrame(df)

# Sorting data for better visualization
df_sorted = df.sort_values(by='bytes')

# Plotting bar graph
fig, ax = plt.subplots(figsize=(10, 8))  # Adjust the figure size as needed

# Bar chart for bytes
bars = ax.barh(df_sorted['age'], df_sorted['bytes'], color='blue', alpha=0.7)

# Adding labels and title
ax.set_xlabel('bytes')
ax.set_ylabel('age')
ax.set_title('Bar Graph of Age vs Bytes')

# Customizing x-axis ticks for better visibility
ax.set_xticks(np.linspace(min(df_sorted['bytes']), max(df_sorted['bytes']), 6))

# Improve layout to prevent overlapping
plt.tight_layout()

# Display the plot
plt.show()

# %%
sales_df = pd.DataFrame(df)

# Find the highest and lowest values in the 'bytes' column
highest_value = sales_df['sales'].max()
lowest_value = sales_df['sales'].min()

# Print the results
print("Highest Value:", highest_value)
print("Lowest Value:", lowest_value)
# Out:
# Highest Value: 11199.968
# Lowest Value: 0.0

# %%
import matplotlib.pyplot as plt


membership_df = {'Normal': 80, 'Premium': 20}

# Create a pie chart
fig, ax = plt.subplots()
ax.pie(membership_df.values(), labels=membership_df.keys(), autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])

# Draw circle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Equal aspect ratio ensures that pie is drawn as a circle
ax.axis('equal')  

# Add a title
plt.title('Membership Distribution')

# Show the pie chart
plt.show()

# %%
plt.bar(df['membership'], df['sales'], color='skyblue')

# Set labels and title
plt.xlabel('Membership')
plt.ylabel('Sales')
plt.title('Membership vs Sales')

# Show the plot
plt.show()

# %%
import pandas as pd


# Find highest and lowest values in the 'duration_(secs)' column
highest_value = df['duration_(secs)'].max()
lowest_value = df['duration_(secs)'].min()

print("Highest value:", highest_value)
print("Lowest value:", lowest_value)
# Out:
# Highest value: 5000
# Lowest value: 1500

# %%
df.head()
# Out:
#    duration_(secs) network_protocol   bytes    accessed_Ffom age  gender  \
# 0             2533            TCP     20100           Chrome  28  Female
# 1             4034            TCP     20500  Mozilla Firefox  21    Male
# 2             1525            TCP     90100  Mozilla Firefox  20    Male
# 3             4572            TCP    100300  Mozilla Firefox  66  Female
# 4             3652            TCP    270200  Mozilla Firefox  53  Female
#
#   country membership language     sales returned  returned_amount   pay_method
# 0      CA     Normal  English  261.9600       No              0.0  Credit Card
# 1      AR     Normal  English  731.9400       No              0.0   Debit Card
# 2      PL     Normal  English   14.6200       No              0.0         Cash
# 3      IN     Normal  Spanish  957.5775       No              0.0  Credit Card
# 4      KR     Normal  Spanish   22.3680       No              0.0         Cash

# %%
# Bar plot to represent sales by gender
sns.barplot(x='gender', y='sales', data=df, estimator=sum)
plt.title('Total Sales by Gender')
plt.xlabel('Gender')
plt.ylabel('Total Sales')
plt.show()

# %%
df
# Out:
#        duration_(secs) network_protocol   bytes    accessed_Ffom age  gender  \
# 0                 2533            TCP     20100           Chrome  28  Female
# 1                 4034            TCP     20500  Mozilla Firefox  21    Male
# 2                 1525            TCP     90100  Mozilla Firefox  20    Male
# 3                 4572            TCP    100300  Mozilla Firefox  66  Female
# 4                 3652            TCP    270200  Mozilla Firefox  53  Female
# ...                ...              ...     ...              ...  ..     ...
# 99452             3439            TCP      4582   Microsoft Edge  45  Female
# 99453             2479            TCP       314   Microsoft Edge  27    Male
# 99454             4231            TCP       281   Microsoft Edge  63    Male
# 99455             3807            TCP        40           Safari  56    Male
# 99456             4479            TCP        46           Safari  36  Female
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Extract the column with non-numeric data
categorical_column = df['returned']

# Initialize label encoder
label_encoder = LabelEncoder()

# Perform label encoding on the categorical column
encoded_categorical_column = label_encoder.fit_transform(categorical_column)

# Replace the original categorical column with the encoded values
df['returned'] = encoded_categorical_column

# %%
df
# Out:
#        duration_(secs) network_protocol   bytes    accessed_Ffom age  gender  \
# 0                 2533            TCP     20100           Chrome  28  Female
# 1                 4034            TCP     20500  Mozilla Firefox  21    Male
# 2                 1525            TCP     90100  Mozilla Firefox  20    Male
# 3                 4572            TCP    100300  Mozilla Firefox  66  Female
# 4                 3652            TCP    270200  Mozilla Firefox  53  Female
# ...                ...              ...     ...              ...  ..     ...
# 99452             3439            TCP      4582   Microsoft Edge  45  Female
# 99453             2479            TCP       314   Microsoft Edge  27    Male
# 99454             4231            TCP       281   Microsoft Edge  63    Male
# 99455             3807            TCP        40           Safari  56    Male
# 99456             4479            TCP        46           Safari  36  Female
#
# ...

# %%
# Label encode categorical variables
label_encoder = LabelEncoder()
for column in df.columns:
    if df[column].dtype == 'object':  # Check if the column has categorical data
        df[column] = label_encoder.fit_transform(df[column])

print("Encoded DataFrame:")
print(df)
# Out:
# Encoded DataFrame:
#        duration_(secs)  network_protocol   bytes  accessed_Ffom  age  gender  \
# 0                 2533                 3   20100              1   11       0
# 1                 4034                 3   20500              4    4       1
# 2                 1525                 3   90100              4    3       1
# 3                 4572                 3  100300              4   49       0
# 4                 3652                 3  270200              4   36       0
# ...                ...               ...     ...            ...  ...     ...
# 99452             3439                 3    4582              3   28       0
# 99453             2479                 3     314              3   10       1
# 99454             4231                 3     281              3   46       1
# 99455             3807                 3      40              7   39       1
# 99456             4479                 3      46              7   19       0
#
# ...

# %%
# LINEAR REGRESSION
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

X=df.drop(['sales_range'],axis=1)
y=df['sales_range']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.35,random_state=30)
X_train.shape,X_test.shape
# Out:
# ((64647, 12), (34810, 12))

# %%
#Creating a linear regression model
model = LinearRegression()
#Fitting the model to the training data
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from math import sqrt

# %%
#Making predictions on the test data
y_pred = model.predict(X_test)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
# Calculate Mean Absolute Error (MAE)
mae1 = mean_absolute_error(y_test, y_pred)
# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
# Calculate R-squared (R²)
r_squared = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae1)
print("Root Mean Squared Error:", rmse)
print("R-squared (R²):", r_squared)
# Out:
# Mean Squared Error: 504655.21144391183
# Mean Absolute Error: 436.7206495437843
# Root Mean Squared Error: 710.3908863744747
# R-squared (R²): 0.07341245662103446

# %%
#KNN REGRESSOR
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=5)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
# Calculate Mean Absolute Error (MAE)
mae3 = mean_absolute_error(y_test, y_pred)
# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
# Calculate R-squared (R²)
r_squared = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae3)
print("Root Mean Squared Error:", rmse)
print("R-squared (R²):", r_squared)
# Out:
# Mean Squared Error: 607722.1819215913
# Mean Absolute Error: 458.2044034174088
# Root Mean Squared Error: 779.565380145624
# R-squared (R²): -0.11582678794196255

# %%
#SUPPORT VECTOR REGESSOR
from sklearn.svm import SVR
model = SVR()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
# Calculate Mean Absolute Error (MAE)
mae4 = mean_absolute_error(y_test, y_pred)
# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
# Calculate R-squared (R²)
r_squared = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae4)
print("Root Mean Squared Error:", rmse)
print("R-squared (R²):", r_squared)
# Out:
# Mean Squared Error: 645016.0579481241
# Mean Absolute Error: 351.6670846682637
# Root Mean Squared Error: 803.1289173900565
# R-squared (R²): -0.184301342820002

# %%
# Create a Gradient Boosting Regressor model with desired hyperparameters
gbr = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3)
gbr.fit(X_train, y_train)

y_pred = gbr.predict(X_test)
y_pred

# Calculate Mean Absolute Error (MAE)
mae5 = mean_absolute_error(y_test, y_pred)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate R-squared (R²)
r_squared = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae5)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared (R²):", r_squared)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 # Create a Gradient Boosting Regressor model with desired hyperparameters
# ----> 2 gbr = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3)
#       3 gbr.fit(X_train, y_train)
#       5 y_pred = gbr.predict(X_test)
#
# NameError: name 'GradientBoostingRegressor' is not defined

# %%
df
